# %% [markdown]
# # Check CLASSIC forcing files
#
# https://cccma.gitlab.io/classic/makeInputFiles.html

# %%
# Env: phd_v3
# To reload external files automatically (ex: utils)
# %load_ext autoreload
# %autoreload 2

import xarray as xr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import proplot as plot # New plot library (https://proplot.readthedocs.io/en/latest/)
plot.rc['savefig.dpi'] = 300 # 1200 is too big! #https://proplot.readthedocs.io/en/latest/basics.html#Creating-figures
from scipy import stats
import xesmf as xe # For regridding (https://xesmf.readthedocs.io/en/latest/)
import calendar

# %% [markdown]
# ## Check FLUXNET site AU-Tum

# %%
path = '/home/lalandmi/eccc/classic-develop/inputFiles/FLUXNETsites/AU-Tum'

# %% [markdown]
# ### SWDown

# %%
ds = xr.open_dataset(path+'/metVar_sw.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 1, lon: 1, time: 227760)
# Coordinates:
#   * lat      (lat) float64 -35.66
#   * lon      (lon) float64 148.2
#   * time     (time) float64 2.001e+07 2.001e+07 ... 2.013e+07 2.013e+07
# Data variables:
#     sw       (time, lat, lon) float64 ...
# Attributes:
#     title:       Incoming short wave radiation
#     units:       J/m2
#     grid_type:   gaussian
#     _FillValue:  1e+38
#     history:     Wed Jun 12 17:19:00 2019: ncks -4 ./metVar_sw.nc ./metVar_sw.nc
#     NCO:         4.4.2

# %%
# The unit shows J/m2 but it seems to be well in W/m2
ds.sw.values.max()
# Out:
# 1197.0

# %%
ds.sw.plot()

# %% [markdown]
# ### LWDown

# %%
ds = xr.open_dataset(path+'/metVar_lw.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 1, lon: 1, time: 227760)
# Coordinates:
#   * lat      (lat) float64 -35.66
#   * lon      (lon) float64 148.2
#   * time     (time) float64 2.001e+07 2.001e+07 ... 2.013e+07 2.013e+07
# Data variables:
#     lw       (time, lat, lon) float64 ...
# Attributes:
#     title:       Incoming long wave radiation
#     units:
#     grid_type:   gaussian
#     _FillValue:  1e+38
#     history:     Wed Jun 12 17:19:00 2019: ncks -4 ./metVar_lw.nc ./metVar_lw.nc
#     NCO:         4.4.2

# %%
ds.lw.plot()

# %% [markdown]
# ### Rainf

# %%
ds = xr.open_dataset(path+'/metVar_pr.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 1, lon: 1, time: 227760)
# Coordinates:
#   * lat      (lat) float64 -35.66
#   * lon      (lon) float64 148.2
#   * time     (time) float64 2.001e+07 2.001e+07 ... 2.013e+07 2.013e+07
# Data variables:
#     pr       (time, lat, lon) float64 ...
# Attributes:
#     title:       Total precipitation
#     units:       mm/hh
#     grid_type:   gaussian
#     _FillValue:  1e+38
#     history:     Wed Jun 12 17:19:00 2019: ncks -4 ./metVar_pr.nc ./metVar_pr.nc
#     NCO:         4.4.2

# %%
ds.pr.plot()

# %% [markdown]
# ### Tair
# /!\ Tair in CLASSIC is in °C /!\ (even if the units show K)

# %%
ds = xr.open_dataset(path+'/metVar_ta.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 1, lon: 1, time: 227760)
# Coordinates:
#   * lat      (lat) float64 -35.66
#   * lon      (lon) float64 148.2
#   * time     (time) float64 2.001e+07 2.001e+07 ... 2.013e+07 2.013e+07
# Data variables:
#     ta       (time, lat, lon) float64 ...
# Attributes:
#     title:       Temperature
#     units:       K
#     grid_type:   gaussian
#     _FillValue:  1e+38
#     history:     Wed Jun 12 17:19:00 2019: ncks -4 ./metVar_ta.nc ./metVar_ta.nc
#     NCO:         4.4.2

# %%
ds.ta.plot()

# %% [markdown]
# ### Qair

# %%
ds = xr.open_dataset(path+'/metVar_qa.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 1, lon: 1, time: 227760)
# Coordinates:
#   * lat      (lat) float64 -35.66
#   * lon      (lon) float64 148.2
#   * time     (time) float64 2.001e+07 2.001e+07 ... 2.013e+07 2.013e+07
# Data variables:
#     qa       (time, lat, lon) float64 ...
# Attributes:
#     title:       Air specific humidity
#     units:       g/g
#     grid_type:   gaussian
#     _FillValue:  1e+38
#     history:     Wed Jun 12 17:19:00 2019: ncks -4 ./metVar_qa.nc ./metVar_qa.nc
#     NCO:         4.4.2

# %%
ds.qa.plot()

# %% [markdown]
# ### Wind

# %%
ds = xr.open_dataset(path+'/metVar_wi.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 1, lon: 1, time: 227760)
# Coordinates:
#   * lat      (lat) float64 -35.66
#   * lon      (lon) float64 148.2
#   * time     (time) float64 2.001e+07 2.001e+07 ... 2.013e+07 2.013e+07
# Data variables:
#     wi       (time, lat, lon) float64 ...
# Attributes:
#     title:       Wind
#     units:       m/s
#     grid_type:   gaussian
#     _FillValue:  1e+38
#     history:     Wed Jun 12 17:19:00 2019: ncks -4 ./metVar_wi.nc ./metVar_wi.nc
#     NCO:         4.4.2

# %%
ds.wi.plot()

# %% [markdown]
# ### Psurf

# %%
ds = xr.open_dataset(path+'/metVar_ap.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 1, lon: 1, time: 227760)
# Coordinates:
#   * lat      (lat) float64 -35.66
#   * lon      (lon) float64 148.2
#   * time     (time) float64 2.001e+07 2.001e+07 ... 2.013e+07 2.013e+07
# Data variables:
#     ap       (time, lat, lon) float64 ...
# Attributes:
#     title:       Atmospheric pressure
#     units:       Pa
#     grid_type:   gaussian
#     _FillValue:  1e+38
#     history:     Wed Jun 12 17:19:00 2019: ncks -4 ./metVar_ap.nc ./metVar_ap.nc
#     NCO:         4.4.2

# %%
ds.ap.plot()
